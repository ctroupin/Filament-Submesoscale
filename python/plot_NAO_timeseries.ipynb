# %%
import os
import glob
import filament
import datetime
import numpy as np
import matplotlib.pyplot as plt

# %%
naodir = "/data/NAO/"
figdir = "/data/NAO/figures"
if not os.path.exists(figdir):
    os.makedirs(figdir)

# %%
file1 = os.path.join(naodir, "nao.long.data")
file2 = os.path.join(naodir, "nao_station_monthly.txt")
file3 = os.path.join(naodir, "norm.nao.monthly.b5001.current.ascii")

# %%
dates1, naovalues1 = filament.read_nao_esrl(file1)
dates2, naovalues2 = filament.read_nao_ucar(file2)
dates3, naovalues3 = filament.read_nao_noaa(file3)

# %%
fig = plt.figure(figsize=(12, 8))
filament.plot_nao_bars(dates1, naovalues1, figname=os.path.join(figdir, "nao_esrl"), width=20)

# %%
fig = plt.figure(figsize=(12, 8))
filament.plot_nao_bars(dates2, naovalues2, figname=os.path.join(figdir, "nao_ucar"), width=20)

# %%
fig = plt.figure(figsize=(12, 8))
filament.plot_nao_bars(dates3, naovalues3, figname=os.path.join(figdir, "nao_noaa"), width=20)

# %%
import matplotlib as mpl

# %%
mpl.get_configdir()
# Out:
# '/home/ctroupin/.config/matplotlib'
