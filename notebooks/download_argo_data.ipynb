# %%
import argopy
from argopy import DataFetcher as ArgoDataFetcher

# %%
argopy.set_options(mode='standard')

# %%
ArgoSet = ArgoDataFetcher().float([4900825])

# %%
ds = ArgoSet.load().data
# Out:
# /home/ctroupin/.virtualenvs/FilamentPaper/lib/python3.11/site-packages/argopy/xarray.py:70: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   self._dims = list(xarray_obj.dims.keys())
# /home/ctroupin/.virtualenvs/FilamentPaper/lib/python3.11/site-packages/argopy/xarray.py:70: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   self._dims = list(xarray_obj.dims.keys())
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ds = ArgoSet.load().data
#
# ...

# %%
ArgoSet.to_dataframe()
# Out:
# /home/ctroupin/.virtualenvs/FilamentPaper/lib/python3.11/site-packages/argopy/xarray.py:70: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   self._dims = list(xarray_obj.dims.keys())
# /home/ctroupin/.virtualenvs/FilamentPaper/lib/python3.11/site-packages/argopy/xarray.py:70: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   self._dims = list(xarray_obj.dims.keys())
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 ArgoSet.to_dataframe()
#
# ...
